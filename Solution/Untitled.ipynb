# %%
import pandas as pd
data = pd.read_csv('./Problem_C_Data_Wordle.CSV',index_col=1,header=1)

data_num_rows, data_num_cols = data.shape
print(f'Data \nNumber of rows : {data_num_rows}\nNumber of columns: {data_num_cols}')

data.head(100)
# Out:
# Data
# Number of rows : 479
# Number of columns: 11
#                       Date   Word  Number of  reported results  \
# Contest number
# 560.0           2022-12-31  manly                      20380.0
# 559.0           2022-12-30  molar                      21204.0
# 558.0           2022-12-29  havoc                      20001.0
# 557.0           2022-12-28  impel                      20160.0
# 556.0           2022-12-27  condo                      20879.0
# ...                    ...    ...                          ...
# 465.0            2022-9-27  soggy                      30985.0
# 464.0            2022-9-26  brisk                      31706.0
# 463.0            2022-9-25  admit                      28994.0
# 462.0            2022-9-24  grate                      32777.0
# 461.0            2022-9-23  glory                      31509.0
#
#                 Number in hard mode  1 try  2 tries  3 tries  4 tries  \
# Contest number
# 560.0                        1899.0    0.0      2.0     17.0     37.0
# 559.0                        1973.0    0.0      4.0     21.0     38.0
# 558.0                        1919.0    0.0      2.0     16.0     38.0
# 557.0                        1937.0    0.0      3.0     21.0     40.0
# 556.0                        2012.0    0.0      2.0     17.0     35.0
# ...                             ...    ...      ...      ...      ...
# 465.0                        2888.0    0.0      2.0     18.0     38.0
# 464.0                        2884.0    0.0      5.0     23.0     38.0
# 463.0                        2677.0    0.0     10.0     25.0     34.0
# 462.0                        3077.0    1.0     14.0     29.0     28.0
# 461.0                        2893.0    0.0      6.0     30.0     39.0
#
#                 5 tries  6 tries  7 or more tries (X)
# Contest number
# 560.0              29.0     12.0                  2.0
# 559.0              26.0      9.0                  1.0
# 558.0              30.0     12.0                  2.0
# 557.0              25.0      9.0                  1.0
# 556.0              29.0     14.0                  3.0
# ...                 ...      ...                  ...
# 465.0              28.0     11.0                  2.0
# 464.0              24.0      7.0                  1.0
# 463.0              22.0      8.0                  1.0
# 462.0              16.0      8.0                  3.0
# 461.0              19.0      5.0                  0.0
#
# [100 rows x 11 columns]

# %%
print("Info of data:")
print(data.info())
# Out:
# Info of data:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 479 entries, 560.0 to nan
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         359 non-null    object
#  1   Word                         359 non-null    object
#  2   Number of  reported results  359 non-null    float64
#  3   Number in hard mode          359 non-null    float64
#  4   1 try                        359 non-null    float64
#  5   2 tries                      359 non-null    float64
#  6   3 tries                      359 non-null    float64
#  7   4 tries                      359 non-null    float64
#  8   5 tries                      359 non-null    float64
#  9   6 tries                      359 non-null    float64
#  10  7 or more tries (X)          359 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 44.9+ KB
# None

# %%
survived = 'survived'
not_survived = 'not survived'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(20, 8))
women = train[train['Sex']=='female']
men = train[train['Sex']=='male']

a = sns.distplot(women[women['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False, color="green")
a = sns.distplot(women[women['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False, color="blue")
a.legend()
a.set_title('Survival Rate for Female')

b = sns.distplot(men[men['Survived']==1].Age.dropna(), bins=40, label = survived, ax = axes[1], kde = False, color="green")
b = sns.distplot(men[men['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False, color="blue")
b.legend()
b = b.set_title('Survival Rate for Male');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_18814/808275186.py in <module>
#       7 data_dn.head(100)
#       8 # 绘制时间序列图
# ----> 9 plt.plot(data_dn)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     493             self.axes.xaxis.update_units(x)
#     494         if self.axes.yaxis is not None:
# --> 495             self.axes.yaxis.update_units(y)
#     496
#     497         if x.shape[0] != y.shape[0]:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in update(self, data)
#     223         # check if convertible to number:
#     224         convertible = True
# --> 225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
#     227             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'
